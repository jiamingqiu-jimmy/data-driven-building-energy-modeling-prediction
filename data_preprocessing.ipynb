# %%
import pandas as pd
import numpy as np
import glob as glob
import fnmatch
import re
from functools import reduce

# %%
# Available names = may, june, july
def get_dir_name(month, year=2020):
    return f"data/{month}_{year}/"

def get_dfs(data_dir):
    csv_files = glob.glob(data_dir + 'Room*.csv')

    def get_room_number(filename):
        pattern = r'Room (\d{3})'
        match = re.search(pattern, filename)
        if match:
            number = match.group(1)
            return number
    exclude_pattern = "*271*"
    filtered_csv_files = [file for file in csv_files if not fnmatch.fnmatch(file, exclude_pattern)]
    print(filtered_csv_files)
    room_numbers = []
    for filename in filtered_csv_files:
        room_numbers.append(get_room_number(filename))
    print(room_numbers)
    print("--- Dataframe processing ---")
    dataframes = dict()
    for file in filtered_csv_files:
        df = pd.read_csv(file)
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])
        df.set_index('Timestamp', inplace=True, drop=False)
        dataframes[get_room_number(file)] = df
    return dataframes

# %%
meta_data = pd.read_csv("data/may_2020/meta.csv")
print(meta_data)

may_df = get_dfs(get_dir_name("may"))
june_df = get_dfs(get_dir_name("june"))
july_df = get_dfs(get_dir_name("july"))
# Out:
#   building_name           start_time             end_time  total_rooms
# 0        NAE-01  2020-05-01 00:00:00  2020-05-31 00:00:00           81  \
#
#   features  line_limit
# 0        h          10
# ['data/may_2020\\Room 104.csv', 'data/may_2020\\Room 105.csv', 'data/may_2020\\Room 107.csv', 'data/may_2020\\Room 108.csv', 'data/may_2020\\Room 110.csv', 'data/may_2020\\Room 114.csv', 'data/may_2020\\Room 120.csv', 'data/may_2020\\Room 121.csv', 'data/may_2020\\Room 122.csv', 'data/may_2020\\Room 208.csv', 'data/may_2020\\Room 213.csv', 'data/may_2020\\Room 216.csv', 'data/may_2020\\Room 217.csv', 'data/may_2020\\Room 221.csv', 'data/may_2020\\Room 223.csv', 'data/may_2020\\Room 227.csv', 'data/may_2020\\Room 229.csv', 'data/may_2020\\Room 240.csv', 'data/may_2020\\Room 245.csv', 'data/may_2020\\Room 247.csv', 'data/may_2020\\Room 248.csv', 'data/may_2020\\Room 249.csv', 'data/may_2020\\Room 252.csv', 'data/may_2020\\Room 254.csv', 'data/may_2020\\Room 261.csv', 'data/may_2020\\Room 264.csv', 'data/may_2020\\Room 268.csv', 'data/may_2020\\Room 280.csv', 'data/may_2020\\Room 281.csv', 'data/may_2020\\Room 288.csv', 'data/may_2020\\Room 290.csv', 'data/may_2020\\Room 302.csv', 'data/may_2020\\Room 304.csv', 'data/may_2020\\Room 308.csv', 'data/may_2020\\Room 314.csv', 'data/may_2020\\Room 317.csv', 'data/may_2020\\Room 323.csv', 'data/may_2020\\Room 328.csv', 'data/may_2020\\Room 329.csv', 'data/may_2020\\Room 330.csv', 'data/may_2020\\Room 336.csv', 'data/may_2020\\Room 340.csv', 'data/may_2020\\Room 345.csv', 'data/may_2020\\Room 348.csv', 'data/may_2020\\Room 350.csv', 'data/may_2020\\Room 353.csv', 'data/may_2020\\Room 361.csv', 'data/may_2020\\Room 362.csv', 'data/may_2020\\Room 363.csv', 'data/may_2020\\Room 368.csv', 'data/may_2020\\Room 371.csv', 'data/may_2020\\Room 375.csv', 'data/may_2020\\Room 380.csv', 'data/may_2020\\Room 386.csv', 'data/may_2020\\Room 387.csv', 'data/may_2020\\Room 402.csv', 'data/may_2020\\Room 403.csv', 'data/may_2020\\Room 405.csv', 'data/may_2020\\Room 409.csv', 'data/may_2020\\Room 413.csv', 'data/may_2020\\Room 415.csv', 'data/may_2020\\Room 417.csv', 'data/may_2020\\Room 420.csv', 'data/may_2020\\Room 423.csv', 'data/may_2020\\Room 428.csv', 'data/may_2020\\Room 429.csv', 'data/may_2020\\Room 432.csv', 'data/may_2020\\Room 436.csv', 'data/may_2020\\Room 437.csv', 'data/may_2020\\Room 445.csv', 'data/may_2020\\Room 448.csv', 'data/may_2020\\Room 450.csv', 'data/may_2020\\Room 453.csv', 'data/may_2020\\Room 461.csv', 'data/may_2020\\Room 462.csv', 'data/may_2020\\Room 463.csv', 'data/may_2020\\Room 469.csv', 'data/may_2020\\Room 470.csv', 'data/may_2020\\Room 484.csv', 'data/may_2020\\Room 490.csv']
# ['104', '105', '107', '108', '110', '114', '120', '121', '122', '208', '213', '216', '217', '221', '223', '227', '229', '240', '245', '247', '248', '249', '252', '254', '261', '264', '268', '280', '281', '288', '290', '302', '304', '308', '314', '317', '323', '328', '329', '330', '336', '340', '345', '348', '350', '353', '361', '362', '363', '368', '371', '375', '380', '386', '387', '402', '403', '405', '409', '413', '415', '417', '420', '423', '428', '429', '432', '436', '437', '445', '448', '450', '453', '461', '462', '463', '469', '470', '484', '490']
# --- Dataframe processing ---
# ['data/june_2020\\Room 104.csv', 'data/june_2020\\Room 105.csv', 'data/june_2020\\Room 107.csv', 'data/june_2020\\Room 108.csv', 'data/june_2020\\Room 110.csv', 'data/june_2020\\Room 114.csv', 'data/june_2020\\Room 120.csv', 'data/june_2020\\Room 121.csv', 'data/june_2020\\Room 122.csv', 'data/june_2020\\Room 208.csv', 'data/june_2020\\Room 213.csv', 'data/june_2020\\Room 216.csv', 'data/june_2020\\Room 217.csv', 'data/june_2020\\Room 221.csv', 'data/june_2020\\Room 223.csv', 'data/june_2020\\Room 227.csv', 'data/june_2020\\Room 229.csv', 'data/june_2020\\Room 240.csv', 'data/june_2020\\Room 245.csv', 'data/june_2020\\Room 247.csv', 'data/june_2020\\Room 248.csv', 'data/june_2020\\Room 249.csv', 'data/june_2020\\Room 252.csv', 'data/june_2020\\Room 254.csv', 'data/june_2020\\Room 261.csv', 'data/june_2020\\Room 264.csv', 'data/june_2020\\Room 268.csv', 'data/june_2020\\Room 280.csv', 'data/june_2020\\Room 281.csv', 'data/june_2020\\Room 288.csv', 'data/june_2020\\Room 290.csv', 'data/june_2020\\Room 302.csv', 'data/june_2020\\Room 304.csv', 'data/june_2020\\Room 308.csv', 'data/june_2020\\Room 314.csv', 'data/june_2020\\Room 317.csv', 'data/june_2020\\Room 323.csv', 'data/june_2020\\Room 328.csv', 'data/june_2020\\Room 329.csv', 'data/june_2020\\Room 330.csv', 'data/june_2020\\Room 336.csv', 'data/june_2020\\Room 340.csv', 'data/june_2020\\Room 345.csv', 'data/june_2020\\Room 348.csv', 'data/june_2020\\Room 350.csv', 'data/june_2020\\Room 353.csv', 'data/june_2020\\Room 361.csv', 'data/june_2020\\Room 362.csv', 'data/june_2020\\Room 363.csv', 'data/june_2020\\Room 368.csv', 'data/june_2020\\Room 371.csv', 'data/june_2020\\Room 375.csv', 'data/june_2020\\Room 380.csv', 'data/june_2020\\Room 386.csv', 'data/june_2020\\Room 387.csv', 'data/june_2020\\Room 402.csv', 'data/june_2020\\Room 403.csv', 'data/june_2020\\Room 405.csv', 'data/june_2020\\Room 409.csv', 'data/june_2020\\Room 413.csv', 'data/june_2020\\Room 415.csv', 'data/june_2020\\Room 417.csv', 'data/june_2020\\Room 420.csv', 'data/june_2020\\Room 423.csv', 'data/june_2020\\Room 428.csv', 'data/june_2020\\Room 429.csv', 'data/june_2020\\Room 432.csv', 'data/june_2020\\Room 436.csv', 'data/june_2020\\Room 437.csv', 'data/june_2020\\Room 445.csv', 'data/june_2020\\Room 448.csv', 'data/june_2020\\Room 450.csv', 'data/june_2020\\Room 453.csv', 'data/june_2020\\Room 461.csv', 'data/june_2020\\Room 462.csv', 'data/june_2020\\Room 463.csv', 'data/june_2020\\Room 469.csv', 'data/june_2020\\Room 470.csv', 'data/june_2020\\Room 484.csv', 'data/june_2020\\Room 490.csv']
# ['104', '105', '107', '108', '110', '114', '120', '121', '122', '208', '213', '216', '217', '221', '223', '227', '229', '240', '245', '247', '248', '249', '252', '254', '261', '264', '268', '280', '281', '288', '290', '302', '304', '308', '314', '317', '323', '328', '329', '330', '336', '340', '345', '348', '350', '353', '361', '362', '363', '368', '371', '375', '380', '386', '387', '402', '403', '405', '409', '413', '415', '417', '420', '423', '428', '429', '432', '436', '437', '445', '448', '450', '453', '461', '462', '463', '469', '470', '484', '490']
# --- Dataframe processing ---
# ['data/july_2020\\Room 104.csv', 'data/july_2020\\Room 105.csv', 'data/july_2020\\Room 107.csv', 'data/july_2020\\Room 108.csv', 'data/july_2020\\Room 110.csv', 'data/july_2020\\Room 114.csv', 'data/july_2020\\Room 120.csv', 'data/july_2020\\Room 121.csv', 'data/july_2020\\Room 122.csv', 'data/july_2020\\Room 208.csv', 'data/july_2020\\Room 213.csv', 'data/july_2020\\Room 216.csv', 'data/july_2020\\Room 217.csv', 'data/july_2020\\Room 221.csv', 'data/july_2020\\Room 223.csv', 'data/july_2020\\Room 227.csv', 'data/july_2020\\Room 229.csv', 'data/july_2020\\Room 240.csv', 'data/july_2020\\Room 245.csv', 'data/july_2020\\Room 247.csv', 'data/july_2020\\Room 248.csv', 'data/july_2020\\Room 249.csv', 'data/july_2020\\Room 252.csv', 'data/july_2020\\Room 254.csv', 'data/july_2020\\Room 261.csv', 'data/july_2020\\Room 264.csv', 'data/july_2020\\Room 268.csv', 'data/july_2020\\Room 280.csv', 'data/july_2020\\Room 281.csv', 'data/july_2020\\Room 288.csv', 'data/july_2020\\Room 290.csv', 'data/july_2020\\Room 302.csv', 'data/july_2020\\Room 304.csv', 'data/july_2020\\Room 308.csv', 'data/july_2020\\Room 314.csv', 'data/july_2020\\Room 317.csv', 'data/july_2020\\Room 323.csv', 'data/july_2020\\Room 328.csv', 'data/july_2020\\Room 329.csv', 'data/july_2020\\Room 330.csv', 'data/july_2020\\Room 336.csv', 'data/july_2020\\Room 340.csv', 'data/july_2020\\Room 345.csv', 'data/july_2020\\Room 348.csv', 'data/july_2020\\Room 350.csv', 'data/july_2020\\Room 353.csv', 'data/july_2020\\Room 361.csv', 'data/july_2020\\Room 362.csv', 'data/july_2020\\Room 363.csv', 'data/july_2020\\Room 368.csv', 'data/july_2020\\Room 371.csv', 'data/july_2020\\Room 375.csv', 'data/july_2020\\Room 380.csv', 'data/july_2020\\Room 386.csv', 'data/july_2020\\Room 387.csv', 'data/july_2020\\Room 402.csv', 'data/july_2020\\Room 403.csv', 'data/july_2020\\Room 405.csv', 'data/july_2020\\Room 409.csv', 'data/july_2020\\Room 413.csv', 'data/july_2020\\Room 415.csv', 'data/july_2020\\Room 417.csv', 'data/july_2020\\Room 420.csv', 'data/july_2020\\Room 423.csv', 'data/july_2020\\Room 428.csv', 'data/july_2020\\Room 429.csv', 'data/july_2020\\Room 432.csv', 'data/july_2020\\Room 436.csv', 'data/july_2020\\Room 437.csv', 'data/july_2020\\Room 445.csv', 'data/july_2020\\Room 448.csv', 'data/july_2020\\Room 450.csv', 'data/july_2020\\Room 453.csv', 'data/july_2020\\Room 461.csv', 'data/july_2020\\Room 462.csv', 'data/july_2020\\Room 463.csv', 'data/july_2020\\Room 469.csv', 'data/july_2020\\Room 470.csv', 'data/july_2020\\Room 484.csv', 'data/july_2020\\Room 490.csv']
# ['104', '105', '107', '108', '110', '114', '120', '121', '122', '208', '213', '216', '217', '221', '223', '227', '229', '240', '245', '247', '248', '249', '252', '254', '261', '264', '268', '280', '281', '288', '290', '302', '304', '308', '314', '317', '323', '328', '329', '330', '336', '340', '345', '348', '350', '353', '361', '362', '363', '368', '371', '375', '380', '386', '387', '402', '403', '405', '409', '413', '415', '417', '420', '423', '428', '429', '432', '436', '437', '445', '448', '450', '453', '461', '462', '463', '469', '470', '484', '490']
# --- Dataframe processing ---

# %%
# concatenate_dict
dfs = {key: pd.concat([may_df[key], june_df[key], july_df[key]]) for key in may_df}

# %%
def filter_dfs(dfs_list, features, resample_interval='30T'):
    def resample_clearNan(df, resample_interval):
        filtered_df = df[~(df['Zone Temperature'] > 100)]
        return filtered_df.dropna().resample(resample_interval).mean()
    filtered_dfs = [resample_clearNan(x, resample_interval)[features] for x in dfs_list]
    return filtered_dfs
rooms_list, dfs_list = zip(*dfs.items())

# %%
def get_temps(dfs_list, resample_interval='30T'):
    list_of_features = ['Zone Temperature']
    temps_x_time_dfs_list = filter_dfs(dfs_list, list_of_features, resample_interval)
    merged_df = temps_x_time_dfs_list[0]
    merged_df = merged_df.rename(columns={'Zone Temperature':f'Zone Temperature_{rooms_list[0]}'})
    for i in range(1, len(temps_x_time_dfs_list)):
        merged_df = pd.merge(merged_df, temps_x_time_dfs_list[i], left_index=True, right_index=True, suffixes=(f"_{rooms_list[i-1]}", f"_{rooms_list[i]}"))
    merged_df = merged_df.dropna()
    merged_df[merged_df.isna().any(axis=1)]
    return merged_df

def get_room_features(dfs_list, resample_interval='30T'):
    list_of_features = dfs_list[0].columns.drop('S.No')
    print(list_of_features)
    features_rooms = filter_dfs(dfs_list, list_of_features, resample_interval)
    # print(features_rooms[0]['Timestamp'][0])

    def series_convert_time_to_num(timestamp):
        return timestamp.dt.hour + timestamp.dt.minute/60 + timestamp.dt.second/3600

    def away_from_time(num, time=2):
        assert time <= 12 and time >= 0
        if num > 12 + time:
            num = 24 - num + time
        else:
            num = np.abs(num - time)
        return num

    for room in features_rooms:
        room['Timestamp'] = series_convert_time_to_num(room['Timestamp']).apply(lambda x: away_from_time(x, 2))
    
    rooms_and_features_list = list()
    for room in features_rooms:
        room = room.drop(room.index[-1]).dropna()
        rooms_and_features_list.append(room)
    return rooms_and_features_list

# %%
def get_data_output(rooms_list, resample_interval='30T'):
    array_room = np.array(rooms_list)
    rooms_and_features = get_room_features(dfs_list, resample_interval)
    array_features_rooms = np.array(rooms_and_features)
    array_temps = np.array(get_temps(dfs_list, resample_interval))
    np.save(f"preprocessing_output/merged_rooms_list.npy", array_room)
    np.save(f"preprocessing_output/merged_features_rooms_{resample_interval}.npy", array_features_rooms)
    np.save(f"preprocessing_output/merged_temps_time_{resample_interval}.npy", array_temps)
    return array_features_rooms, array_temps

# %%
a,b = get_data_output(rooms_list=rooms_list, resample_interval='30T')
get_data_output(rooms_list=rooms_list, resample_interval='60T')
get_data_output(rooms_list=rooms_list, resample_interval='120T')
# Out:
# Index(['Timestamp', 'Zone Temperature', 'Warm/Cool Adjust', 'Supply Vol Press',
#        'Actual Cooling Setpt', 'Actual Heating Setpt',
#        'Actual Damper Position', 'Actual Supply Flow', 'Reheat Valve Command',
#        'Common Setpoint', 'Damper Command', 'Actual Sup Flow SP',
#        'Cooling Max Flow', 'Occupied Clg Min', 'Occupied Htg Flow',
#        'Cooling Command', 'Heating Command', 'Occupied Command',
#        'Occupied Status'],
#       dtype='object')
# Index(['Timestamp', 'Zone Temperature', 'Warm/Cool Adjust', 'Supply Vol Press',
#        'Actual Cooling Setpt', 'Actual Heating Setpt',
#        'Actual Damper Position', 'Actual Supply Flow', 'Reheat Valve Command',
#        'Common Setpoint', 'Damper Command', 'Actual Sup Flow SP',
#        'Cooling Max Flow', 'Occupied Clg Min', 'Occupied Htg Flow',
#        'Cooling Command', 'Heating Command', 'Occupied Command',
#        'Occupied Status'],
#       dtype='object')
# Index(['Timestamp', 'Zone Temperature', 'Warm/Cool Adjust', 'Supply Vol Press',
#        'Actual Cooling Setpt', 'Actual Heating Setpt',
#        'Actual Damper Position', 'Actual Supply Flow', 'Reheat Valve Command',
#        'Common Setpoint', 'Damper Command', 'Actual Sup Flow SP',
#        'Cooling Max Flow', 'Occupied Clg Min', 'Occupied Htg Flow',
#        'Cooling Command', 'Heating Command', 'Occupied Command',
#        'Occupied Status'],
#       dtype='object')
# (array([[[ 3.79166667e+00,  7.59069157e+01,  2.47019005e+00, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 5.08333333e+00,  7.53342688e+01,  2.47019005e+00, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 6.95833333e+00,  7.47698364e+01,  2.47019005e+00, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          ...,
#          [ 9.04166667e+00,  7.24322433e+01, -8.44084024e-01, ...,
#            0.00000000e+00,  3.00000000e+00,  3.00000000e+00],
#          [ 7.04166667e+00,  7.29996777e+01, -8.44084024e-01, ...,
#            0.00000000e+00,  3.00000000e+00,  3.00000000e+00],
#          [ 5.04166667e+00,  7.34405746e+01, -8.44084024e-01, ...,
#            0.00000000e+00,  3.00000000e+00,  3.00000000e+00]],
#
#         [[ 3.79166667e+00,  7.14588242e+01,  3.89255905e+00, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 5.08333333e+00,  7.12430147e+01,  3.89255905e+00, ...,
#            4.77343618e+01,  1.00000000e+00,  1.00000000e+00],
#          [ 6.95833333e+00,  7.09552689e+01,  3.89255905e+00, ...,
#            1.00000000e+02,  1.00000000e+00,  1.00000000e+00],
#          ...,
#          [ 9.04166667e+00,  7.53647614e+01,  4.12800360e+00, ...,
#            3.75818520e+01,  3.00000000e+00,  3.00000000e+00],
#          [ 7.04166667e+00,  7.53647614e+01,  4.12800360e+00, ...,
#            3.53934508e+01,  3.00000000e+00,  3.00000000e+00],
#          [ 5.04166667e+00,  7.53647614e+01,  4.12800360e+00, ...,
#            3.73263470e+01,  3.00000000e+00,  3.00000000e+00]],
#
#         [[ 3.79166667e+00,  7.14588242e+01, -1.57884359e-02, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 5.08333333e+00,  7.12430147e+01, -1.57884359e-02, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 6.95833333e+00,  7.09552689e+01, -1.57884359e-02, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          ...,
#          [ 9.04166667e+00,  7.53647614e+01, -3.38414907e-02, ...,
#            0.00000000e+00,  3.00000000e+00,  3.00000000e+00],
#          [ 7.04166667e+00,  7.53647614e+01, -3.38414907e-02, ...,
#            0.00000000e+00,  3.00000000e+00,  3.00000000e+00],
#          [ 5.04166667e+00,  7.53647614e+01, -3.38414907e-02, ...,
#            0.00000000e+00,  3.00000000e+00,  3.00000000e+00]],
#
#         ...,
#
#         [[ 3.79166667e+00,  7.71274719e+01,  3.24534273e+00, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 5.08333333e+00,  7.71274719e+01,  3.24534273e+00, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 6.95833333e+00,  7.70007401e+01,  3.24534273e+00, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          ...,
#          [ 9.04166667e+00,  7.53209457e+01,  3.17255926e+00, ...,
#            0.00000000e+00,  3.00000000e+00,  3.00000000e+00],
#          [ 7.04166667e+00,  7.53209457e+01,  3.17255926e+00, ...,
#            0.00000000e+00,  3.00000000e+00,  3.00000000e+00],
#          [ 5.04166667e+00,  7.53209457e+01,  3.17255926e+00, ...,
#            0.00000000e+00,  3.00000000e+00,  3.00000000e+00]],
#
#         [[ 3.79166667e+00,  7.15118942e+01,  2.67115021e+00, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 5.08333333e+00,  7.15118942e+01,  2.67115021e+00, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 6.95833333e+00,  7.14908012e+01,  2.67115021e+00, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          ...,
#          [ 9.04166667e+00,  7.07253313e+01,  2.68340635e+00, ...,
#            2.80499849e+01,  3.00000000e+00,  3.00000000e+00],
#          [ 7.04166667e+00,  7.07035319e+01,  2.68340635e+00, ...,
#            2.84977514e+01,  3.00000000e+00,  3.00000000e+00],
#          [ 5.04166667e+00,  7.07469591e+01,  2.68340635e+00, ...,
#            2.82428960e+01,  3.00000000e+00,  3.00000000e+00]],
#
#         [[ 3.79166667e+00,  7.15118942e+01,  5.55290699e-01, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 5.08333333e+00,  7.15118942e+01,  5.55290699e-01, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          [ 6.95833333e+00,  7.14908012e+01,  5.55290699e-01, ...,
#            0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#          ...,
#          [ 9.04166667e+00,  7.07253313e+01,  9.13000226e-01, ...,
#            1.27456222e+01,  3.00000000e+00,  3.00000000e+00],
#          [ 7.04166667e+00,  7.07035319e+01,  9.13000226e-01, ...,
#            1.18014786e+01,  3.00000000e+00,  3.00000000e+00],
#          [ 5.04166667e+00,  7.07469591e+01,  9.13000226e-01, ...,
#            1.85222118e+01,  3.00000000e+00,  3.00000000e+00]]]),
#  array([[75.90691566, 71.45882416, 71.45882416, ..., 77.12747192,
#          71.51189423, 71.51189423],
#         [75.33426884, 71.24301474, 71.24301474, ..., 77.12747192,
#          71.51189423, 71.51189423],
#         [74.76983643, 70.95526886, 70.95526886, ..., 77.00074005,
#          71.49080118, 71.49080118],
#         ...,
#         [72.99967766, 75.36476135, 75.36476135, ..., 75.32094574,
#          70.7035319 , 70.7035319 ],
#         [73.44057465, 75.36476135, 75.36476135, ..., 75.32094574,
#          70.74695905, 70.74695905],
#         [73.44057465, 75.36476135, 75.36476135, ..., 75.32094574,
#          70.68974241, 70.68974241]]))
